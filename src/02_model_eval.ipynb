# %%
import pickle
import utils
import torch.nn as nn

# %%
with open('final_model/final.model.pickle','rb') as model_file:
     model = pickle.load(model_file)

criterion = nn.NLLLoss()

# %%
test_loader = utils.create_data_loader(['batches/test/'], batch_size=1, shuffle=False)

# %%
utils.evaluate_classification(model, criterion, test_loader)
# Out:
# Model evaluation on: <torch.utils.data.dataloader.DataLoader object at 0x7f9ddc10c6d0>
# Accuracy: 0.3506
# Precision: 0.4532
# Recall: 0.3506
# F1 Score: 0.3287
# (1.5218418723060971, 0.35060975609756095)
