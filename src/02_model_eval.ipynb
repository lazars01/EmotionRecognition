# %%
import pickle
import utils
import torch.nn as nn

# %%
with open('final_model/final.model.pickle','rb') as model_file:
     model = pickle.load(model_file)

criterion = nn.CrossEntropyLoss()

# %%
test_loader = utils.create_data_loader(['../batches/test/'], batch_size=1, shuffle=False)

# %%
utils.evaluate_classification(model, criterion, test_loader)
# Out:
# Model evaluation on: <torch.utils.data.dataloader.DataLoader object at 0x7f73d3aa3a90>
# Accuracy: 0.4146
# Precision: 0.4898
# Recall: 0.4146
# F1 Score: 0.4204
# (1.4830872842243739, 0.4146341463414634)
